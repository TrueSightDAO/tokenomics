# %%
# Importing for system files
import os
import sys
import csv
import pprint

# %%
# Loading environmental variables 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Import System Files
dir_path = os.path.dirname(os.path.realpath('__file__'))
sys.path.append(dir_path + '/lib/')  
from process_work import process_work

# %%
# For processing WhatsApp data file
from whatstk import df_from_txt_whatsapp
from whatstk.data import whatsapp_urls

# Date before which chat is not scored
cut_off_date = 20231022

# %%
# file_key = '20231213_townhall_chat'
# file_key = '20231213_beerhall_chat'
# file_key = '20231214_agroverse_chat'
file_key = '20231214_main_dao_website_chat'

# %%
# Importing WhatsApp data file
df = df_from_txt_whatsapp(filepath=f"./data/{file_key}.txt")
df.head(100)

# Setup work analysis file
analysis_file = open(f"analysis/{file_key}.csv", 'w')
analysis_writer = csv.writer(analysis_file)

header = ['Contributor Name', 'Contribution Made', 'Rubric classification', 'TDGs Issued', 'Status date']
# data = ['Afghanistan', 652090, 'AF', 'AFG']
analysis_writer.writerow(header)

pp = pprint.PrettyPrinter(indent=4)

# %%
# For OpenAI client
from openai import OpenAI

# Acquire OpenAI API Key via this URL 
#    https://platform.openai.com/api-keys
# Save Secret in .env file with 
#    OPENAI_API_KEY=YOUR SECRET KEY

openai_client = OpenAI(
    # This is the default and can be omitted
    api_key=os.environ.get("OPENAI_API_KEY"),
)

# %%
total_rows = df.count()['date']

# %%
# Calling OpenAi API to get time taken for work done
def check_tdg_issued(work_description):
    payload = f"We award 100TDG for every hour of contribution made that was explicitly reported in the Action Description. \
                We award 1.666666666666667TDG for every minute of contribution made that was explicitly reported in the Action Description. \
                 Amount of TDG issued should be prorated based on actual time explicitly reported\
                 Time taken indicated in the 'Action Description' may also appear in the following formats as a stand alone sentences\
                     Time Taken : X Hours \
                     Time Taken : Y Minutes \
                     \
                 We award 1TDG for each USD of expenses paid for onbehalf by DAO member \
                 There are only two available options for 'Rubric classification' and they are: \
                     'Contributed Fiat Funding' \
                     'Contributed Human Effort' \
                     \
                 Response must be short and concise\
                 Response must be in a single line CSV format. Response must not include headers\
                     Rubric classification (String); TDGs Issued (Integer)\
                     \
                 If Action Description does not make sense return the following values \
                     Unknown; 0 \
                     \
                 For the following 'Action Description' determine Rubric classification and TDGs Issued \
                     \
                 Action Description:\
                 {work_description}."
    
    work_process_completion = openai_client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": payload,
            }
        ],
        model="gpt-3.5-turbo",
    )
    return work_process_completion.choices[0].message.content

# response = check_tdg_issued("Gary Teh walked the dog for 1 hour")

# %%
for index, row in df.iterrows():

    # Doesn't process record if occurred before a specific date
    if int(row['date'].strftime(format)) < cut_off_date:
        continue
    
    clean_work_description = row['message'].encode('ascii','ignore') 
    response = check_tdg_issued(clean_work_description)
    openai_result = response.split(';')
    
    classification = "Unknown"
    tdg_issue = 0
    
    if len(openai_result) == 2:
        classification = openai_result[0]
        tdg_issue = openai_result[1]

    format = '%Y%m%d'

    20231023

    # header = ['Contributor Name', 'Contribution Made', 'Rubric classification', 'TDGs Issued', 'Status date']
    data = [
        row['username'], 
        row['message'], 
        classification, 
        tdg_issue, 
        row['date'].strftime(format)
    ]
    print("")
    print(f"Processing {index} of {total_rows}: ")
    pp.pprint(response)
    pp.pprint(openai_result)
    pp.pprint(len(openai_result))
    pp.pprint(data)
    
    
    analysis_writer.writerow(data)
# Out:
# Processing 0 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '*Tokenization completed event - 20231023*',
#     'Unknown',
#     ' 0',
#     '20231023']
#
# Processing 2 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Matheus Reis - Bahia Coop', 'To be honest I do.', 'Unknown', ' 0', '20231023']
#
# Processing 4 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Matheus Reis - Bahia Coop',
#     'Yessss.. that was the answer Maax gave to me',
#     'Unknown',
#     ' 0',
#     '20231023']
#
# Processing 6 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     'Could you ask Max what is the Brazilian government regulation for a '
#     'Brazilian company issuing cryptocurrency tokens?',
#     'Contributed Human Effort',
#     ' 0',
#     '20231023']
#
# Processing 8 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     '@31641075825 this reel looks really good. Did you created it?\n'
#     'https://www.instagram.com/p/CywI5luoshI/ Or did you get help from '
#     '@972543523823?\n'
#     '\n'
#     'Trying to update our ledger with efforts on Instagram now \u200e<This '
#     'message was edited>',
#     'Contributed Human Effort',
#     ' 0',
#     '20231023']
#
# Processing 10 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Val Lapidus',
#     '@31641075825 the text in this video is too fast, it needs to slow down',
#     'Unknown',
#     ' 0',
#     '20231023']
#
# Processing 12 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Matheus Reis - Bahia Coop',
#     "I belive we don't have it yet.",
#     'Unknown',
#     ' 0',
#     '20231023']
#
# Processing 14 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Matheus Reis - Bahia Coop', "But I'll ask", 'Unknown', ' 0', '20231023']
#
# Processing 16 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231023']
#
# Processing 18 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Suheil - Europe',
#     'with annia always, i never move alone 😛',
#     'Unknown',
#     ' 0',
#     '20231024']
#
# Processing 20 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Suheil - Europe',
#     'will get on call with them again today',
#     'Contributed Human Effort',
#     ' 0',
#     '20231024']
#
# Processing 22 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231024']
#
# Processing 24 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231024']
#
# Processing 26 of 2021:
# 'Contributed Human Effort; 10'
# ['Contributed Human Effort', ' 10']
# 2
# [   'Val Lapidus',
#     'To make cacao syrup i used:\n500mL hot water (2 cups)\n6oz cacao nibs',
#     'Contributed Human Effort',
#     ' 10',
#     '20231024']
#
# Processing 28 of 2021:
# 'Contributed Human Effort; 200'
# ['Contributed Human Effort', ' 200']
# 2
# [   'Gary Teh',
#     'Pricing tier report generation\n\n*Time taken: 2 hours*',
#     'Contributed Human Effort',
#     ' 200',
#     '20231024']
#
# Processing 30 of 2021:
# 'Contributed Human Effort; 4'
# ['Contributed Human Effort', ' 4']
# 2
# [   'Gary Teh',
#     '@16468233438 could you provide @557191035605 with details of the 1st Nov '
#     'venue?\n'
#     '\n'
#     'She is inserting events on Agroverse.shop\n'
#     '\u200e',
#     'Contributed Human Effort',
#     ' 4',
#     '20231024']
#
# Processing 32 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', 'I have provided these\n\u200e', 'Unknown', ' 0', '20231024']
#
# Processing 34 of 2021:
# 'Contributed Human Effort; 100 TDGs'
# ['Contributed Human Effort', ' 100 TDGs']
# 2
# [   'Gary Teh',
#     '*Friday*\n'
#     'https://www.meetup.com/hackerdojo/events/296688947/\n'
#     'Name of Event: HALLOWEEKEND\n'
#     'Date: 27th Sept 2023\n'
#     'Venue: HackerDojo\n'
#     'No products sold. Cold brew cacao being served\n'
#     '\u200e',
#     'Contributed Human Effort',
#     ' 100 TDGs',
#     '20231024']
#
# Processing 36 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     '*Thursday*\n'
#     'https://www.eventbrite.com/e/happy-hour-at-edge-nodes-house-of-web3-tickets-740383225157?aff=oddtdtcreator\n'
#     'Name of Event: Happy Hour\n'
#     'Date 26th Sept 2023\n'
#     'Venue:  Edge and Node - House of Web3\n'
#     'No products sold. Cold brew cacao being served\n'
#     '\u200e',
#     'Contributed Human Effort',
#     ' 0',
#     '20231024']
#
# Processing 38 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231024']
#
# Processing 40 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '@31641075825 and @972543523823 shall we start applying the branding '
#     'guidelines in our post on Instagram?',
#     'Unknown',
#     ' 0',
#     '20231024']
#
# Processing 42 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'Tess surfaced this cold brew cacao competitor\n'
#     'https://criobru.com/pages/fall-wss21',
#     'Unknown',
#     ' 0',
#     '20231024']
#
# Processing 44 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     'Tess surfaced this superfoods competitor on Amazon\n'
#     'https://www.amazon.com/stores/page/928C843E-7C95-4963-8D8F-A8C1B83D6CC2\n'
#     '\n'
#     'I actually wonder how they created their shopfront',
#     'Contributed Human Effort',
#     ' 0',
#     '20231024']
#
# Processing 46 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Suheil - Europe', 'yes we should', 'Unknown', ' 0', '20231025']
#
# Processing 48 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Suheil - Europe',
#     'i saw the possibility iin their back office. we can do that once we have '
#     'multiple products…yet meanwhile i prefer to risk on building direct '
#     'front….',
#     'Unknown',
#     ' 0',
#     '20231025']
#
# Processing 50 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     '@16468233438 I understand that you and Kevin will be working on the '
#     'brochure that we will be circulating to the retailers / franchisers we '
#     'will be reaching out to.\n'
#     '\n'
#     'I will just go ahead and compile a contact list of the small shop '
#     'retailers we should be reaching out to here in the Bay Area',
#     'Contributed Human Effort',
#     ' 0',
#     '20231025']
#
# Processing 52 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Anupa/diya',
#     'Is there a buyers wholesale brochure',
#     'Unknown',
#     ' 0',
#     '20231025']
#
# Processing 54 of 2021:
# 'Contributed Human Effort; 6'
# ['Contributed Human Effort', ' 6']
# 2
# [   'Anupa/diya',
#     'Emelin can u share the guidelines',
#     'Contributed Human Effort',
#     ' 6',
#     '20231025']
#
# Processing 56 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', 'Here @918017107841', 'Unknown', ' 0', '20231025']
#
# Processing 58 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Suheil - Europe', 'guyz', 'Unknown', ' 0', '20231025']
#
# Processing 60 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Suheil - Europe',
#     'when is the next event u are attending offlnie',
#     'Unknown',
#     ' 0',
#     '20231025']
#
# Processing 62 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Suheil - Europe',
#     'offline and where or what or share links or sthn….thinking about posting '
#     'story of today. about iit sort of calling people ini the area to come '
#     'meet us',
#     'Contributed Human Effort',
#     ' 0',
#     '20231025']
#
# Processing 64 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     'Gary sent about the events yesterday. It is here on the conversation.',
#     'Unknown',
#     ' 0',
#     '20231025']
#
# Processing 66 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     'there is one 1st Nov. Talk to @16468233438',
#     'Unknown',
#     ' 0',
#     '20231025']
#
# Processing 68 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     "I don't have this information yet",
#     'Unknown',
#     ' 0',
#     '20231025']
#
# Processing 70 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '@31641075825', 'Unknown', ' 0', '20231025']
#
# Processing 72 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '@31641075825', 'Unknown', ' 0', '20231025']
#
# Processing 74 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '@16468233438 needs to share', 'Unknown', ' 0', '20231025']
#
# Processing 76 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231025']
#
# Processing 78 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231025']
#
# Processing 80 of 2021:
# 'Contributed Human Effort; 50'
# ['Contributed Human Effort', ' 50']
# 2
# [   'Gary Teh',
#     'Generated a list of *313 chocolatiers* based here in the bay to start '
#     'doing *cold calling*. \n'
#     '\n'
#     '*Time taken: 30 minutes*\n'
#     'https://docs.google.com/spreadsheets/d/1i6UBg7_WQDualz5HmMxhY29g18mUMOD_lep6rr-ggOs/edit?usp=sharing '
#     '\u200e<This message was edited>',
#     'Contributed Human Effort',
#     ' 50',
#     '20231025']
#
# Processing 82 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231025']
#
# Processing 84 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     '\u200eYou deleted this message.',
#     'Contributed Human Effort',
#     ' 0',
#     '20231025']
#
# Processing 86 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231025']
#
# Processing 88 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'agroverse xilogravuras.ai \u200edocument omitted',
#     'Unknown',
#     ' 0',
#     '20231025']
#
# Processing 90 of 2021:
# 'Contributed Human Effort; 23'
# ['Contributed Human Effort', ' 23']
# 2
# [   'Gary Teh',
#     '14X Illustrations generated by @557191035605',
#     'Contributed Human Effort',
#     ' 23',
#     '20231025']
#
# Processing 92 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'I remember having this when in Northern Europe (Copenhagen) the year '
#     'before last during Christmas period \n'
#     '\n'
#     'https://www.justataste.com/easy-homemade-churros-chocolate-sauce-recipe/ '
#     '\u200e<This message was edited>',
#     'Unknown',
#     ' 0',
#     '20231025']
#
# Processing 94 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eYou deleted this message.', 'Unknown', ' 0', '20231025']
#
# Processing 96 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eGIF omitted', 'Unknown', ' 0', '20231025']
#
# Processing 98 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '*Conventions and events*\n'
#     '\n'
#     'https://retailfest.us/\n'
#     'https://www.sipshopeat.com/bay-area-irl-pop-up\n'
#     'https://www.kidfestconcord.com/exhibitors\n'
#     'https://eventhub.net/profiles/BayAreaFestivals \u200e<This message was '
#     'edited>',
#     'Unknown',
#     ' 0',
#     '20231025']
#
# Processing 100 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     'Yes, yes annnd yes. Churros is sooo good',
#     'Unknown',
#     ' 0',
#     '20231025']
#
# Processing 102 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eGIF omitted', 'Unknown', ' 0', '20231025']
#
# Processing 104 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Val Lapidus',
#     'https://sunsetmercantilesf.com/diadelosmuertos/',
#     'Unknown',
#     ' 0',
#     '20231025']
#
# Processing 106 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Val Lapidus',
#     "@14153000019 if you are voluntolding me, that's fine",
#     'Unknown',
#     ' 0',
#     '20231025']
#
# Processing 108 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'That what you told me yesterday.\n'
#     '\n'
#     'I sent it here for ledger update later',
#     'Unknown',
#     ' 0',
#     '20231025']
#
# Processing 110 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231025']
#
# Processing 112 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231025']
#
# Processing 114 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231025']
#
# Processing 116 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231025']
#
# Processing 118 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231026']
#
# Processing 120 of 2021:
# 'Contributed Human Effort; 150TDG'
# ['Contributed Human Effort', ' 150TDG']
# 2
# [   'Gary Teh',
#     'Submission of time taken for me and @16468233438 to prepare this\n'
#     '\n'
#     '*Time Taken: 1.5 hours*',
#     'Contributed Human Effort',
#     ' 150TDG',
#     '20231026']
#
# Processing 122 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'Generate a new sticker label for our container\n'
#     '\n'
#     'https://github.com/TrueSightDAO/.github/blob/main/assets/20231026%20-%20Agroverse%20Container%20Sticker%20Label%20Print%20OUt%20-%20Google%20Docs.pdf',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 124 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', 'Guys,', 'Unknown', ' 0', '20231026']
#
# Processing 126 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', '\u200eimage omitted', 'Unknown', ' 0', '20231026']
#
# Processing 128 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', '6:00 PM to 9:00 PM?', 'Unknown', ' 0', '20231026']
#
# Processing 130 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# ['Gary Teh', 'Yes! 🙂🙏', 'Contributed Human Effort', ' 0', '20231026']
#
# Processing 132 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', '\u200eimage omitted', 'Unknown', ' 0', '20231026']
#
# Processing 134 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# ['Emelin - Bahia', 'ok', 'Contributed Human Effort', ' 0', '20231026']
#
# Processing 136 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', '🥸', 'Unknown', ' 0', '20231026']
#
# Processing 138 of 2021:
# 'Contributed Human Effort; 3'
# ['Contributed Human Effort', ' 3']
# 2
# [   'Suheil - Europe',
#     'https://instagram.com/stories/agroverse.shop/3222067235512136540?utm_source=ig_story_item_share&igshid=MTc4MmM1YmI2Ng==\n'
#     '\n'
#     'This was a "late" sample.\n'
#     '\n'
#     'We should make it better by being "fresh" : \n'
#     '- before you attending events we announce  --> during event u live or '
#     'story',
#     'Contributed Human Effort',
#     ' 3',
#     '20231026']
#
# Processing 140 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Emelin - Bahia',
#     'It says it is from Hacker Dojo and internet tells me it is in the Silicon '
#     'Valley. So I will add the adress.',
#     'Contributed Human Effort',
#     ' 0',
#     '20231026']
#
# Processing 142 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', '\u200eimage omitted', 'Unknown', ' 0', '20231026']
#
# Processing 144 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', '\u200eimage omitted', 'Unknown', ' 0', '20231026']
#
# Processing 146 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     'I need some feedback from someone from USA. @14153000019 @16468233438',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 148 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', '\u200eimage omitted', 'Unknown', ' 0', '20231026']
#
# Processing 150 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', '\u200eimage omitted', 'Unknown', ' 0', '20231026']
#
# Processing 152 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', 'really nice though', 'Unknown', ' 0', '20231026']
#
# Processing 154 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', 'It has more content', 'Unknown', ' 0', '20231026']
#
# Processing 156 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', 'the videos are cool as well', 'Unknown', ' 0', '20231026']
#
# Processing 158 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', ':D', 'Unknown', ' 0', '20231026']
#
# Processing 160 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Suheil - Europe',
#     'Will not lie that our work (with @972543523823 ) due to actual estate is '
#     'still not coming from the heart 🤷\u200d♂️🤷\u200d♂️',
#     'Contributed Human Effort',
#     ' 0',
#     '20231026']
#
# Processing 162 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Suheil - Europe',
#     'I know we can do better but maaaan situation so fucked lol',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 164 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Suheil - Europe',
#     'Sorry for my language',
#     'Contributed Human Effort',
#     ' 0',
#     '20231026']
#
# Processing 166 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Suheil - Europe', 'But no other way to express', 'Unknown', ' 0', '20231026']
#
# Processing 168 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     'Things that might help: use our own brand illustration as possible, avoid '
#     'using dynamic texts too much, texts must come aligned to the left and '
#     'give some space between the Insta name and the pictures/videos.',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 170 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', 'I understand', 'Unknown', ' 0', '20231026']
#
# Processing 172 of 2021:
# 'Contributed Human Effort; 9600'
# ['Contributed Human Effort', ' 9600']
# 2
# [   'Emelin - Bahia',
#     'I worked the whole day doing social media and these small tips really '
#     'become mechanic.\n'
#     '\u200e',
#     'Contributed Human Effort',
#     ' 9600',
#     '20231026']
#
# Processing 174 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# ['Suheil - Europe', 'Agree', 'Contributed Human Effort', ' 0', '20231026']
#
# Processing 176 of 2021:
# 'Contributed Human Effort; 100TDG'
# ['Contributed Human Effort', ' 100TDG']
# 2
# [   'Emelin - Bahia',
#     'you can align to the center as well when it matches the proposal.',
#     'Contributed Human Effort',
#     ' 100TDG',
#     '20231026']
#
# Processing 178 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     'I forgot to add. I will add, hold on a sec',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 180 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Emelin - Bahia',
#     'Things that might help: use our own brand illustration as possible, avoid '
#     'using dynamic texts too much, texts must come aligned to the left or '
#     'centered, and give some space between the Insta name and the '
#     'pictures/videos.',
#     'Contributed Human Effort',
#     ' 0',
#     '20231026']
#
# Processing 182 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Emelin - Bahia',
#     'Now, copy and paste on the notepad. I can do a checklist if you want as '
#     'well.',
#     'Contributed Human Effort',
#     ' 0',
#     '20231026']
#
# Processing 184 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     'it is easier to create things when we have some rules defined. Less time '
#     'thinking :D more time to rest.',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 186 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', '\u200eGIF omitted', 'Unknown', ' 0', '20231026']
#
# Processing 188 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     'Noooow a happy kitten dancing to cheer up the day. Stay safe.',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 190 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     '*Waiting for the November 1st update*',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 192 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', '@16468233438', 'Unknown', ' 0', '20231026']
#
# Processing 194 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     '\u200eThis message was deleted.',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 196 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Emelin - Bahia',
#     '@31641075825 this event can be promoted on Insta: '
#     'https://www.meetup.com/hackerdojo/events/29668a8947/',
#     'Contributed Human Effort',
#     ' 0',
#     '20231026']
#
# Processing 198 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     'It will happen today (friday 27)',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 200 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     'post-de-instagram-de-cafeteria-moderna.zip \u200edocument omitted',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 202 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     'These are some models you can edit over. Remove the texture though.',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 204 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     'modelo-de-postagem-de-midia-social-de-condicionamento-fisico.zip '
#     '\u200edocument omitted',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 206 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Emelin - Bahia',
#     "I haven't been able to add the previous events because I've swamped. For "
#     'this, I say sorry and compromise to post them weekly. If an event pops, '
#     'just send me guys.\n'
#     '\u200e',
#     'Contributed Human Effort',
#     ' 0',
#     '20231026']
#
# Processing 208 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'Let me take a look in the morning 🙂🙏',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 210 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'Tickets are not necessary \n'
#     '\n'
#     'They just created the event for marketing purposes',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 212 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     'It is something that comes with Wix\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 214 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     'They just published it on their meetup.com profile\n'
#     '\n'
#     'Nothing much we need to do on our end\n'
#     '\n'
#     'We are just riding on their marketing efforts by presenting our CTA at '
#     'their events \u200e<This message was edited>',
#     'Contributed Human Effort',
#     ' 0',
#     '20231026']
#
# Processing 216 of 2021:
# 'Contributed Human Effort; 110 TDGs'
# ['Contributed Human Effort', ' 110 TDGs']
# 2
# [   'Emelin - Bahia',
#     'I added the Halloween event on the page, added the Instagram adress in '
#     'two sections (still think we need to rethink the experience with the '
#     'tracking your package and share with us your story - because it requires '
#     'some attention of a social media schedule to show people how to do it and '
#     'why to do it (a 3 posts slide would work) and sent Suheil two templates '
#     'that can help with the posting, reminding to use our own identity. The '
#     'time was 23:20 to 00:29.',
#     'Contributed Human Effort',
#     ' 110 TDGs',
#     '20231026']
#
# Processing 218 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# ['Emelin - Bahia', 'I saw it.', 'Contributed Human Effort', ' 0', '20231026']
#
# Processing 220 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', 'Thanls', 'Unknown', ' 0', '20231026']
#
# Processing 222 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', 'Thanks', 'Unknown', ' 0', '20231026']
#
# Processing 224 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', '\u200eimage omitted', 'Unknown', ' 0', '20231026']
#
# Processing 226 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     'Have a nice night/day you all.',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 228 of 2021:
# 'Contributed Human Effort; 87'
# ['Contributed Human Effort', ' 87']
# 2
# [   'Gary Teh',
#     'That is wonderful!\n'
#     '\n'
#     'Will follow up with @16468233438 when I meet him tomorrow to get more '
#     'details about the night market\n'
#     '\n'
#     'Also we are going to be partnering up with Edge and Node for their '
#     'anniversary celebration event on the 9th of Nov',
#     'Contributed Human Effort',
#     ' 87',
#     '20231026']
#
# Processing 230 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Emelin - Bahia',
#     'Obs: we should have a section with pictures from the events that '
#     'redirects to the Instagram as well. As it is done in the shop part. Any '
#     'opportunity we can use to make people curious about Agroverse, we should '
#     'use.',
#     'Contributed Human Effort',
#     ' 0',
#     '20231026']
#
# Processing 232 of 2021:
# 'Contributed Human Effort; 100 TDGs Issued'
# ['Contributed Human Effort', ' 100 TDGs Issued']
# 2
# [   'Emelin - Bahia',
#     'I wrote some "what I get in return if I go to your event?"',
#     'Contributed Human Effort',
#     ' 100 TDGs Issued',
#     '20231026']
#
# Processing 234 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     '"You will taste our fine cocoa drink and benefit your diet by having the '
#     'opportunity to talk to our collaborators and learn more about the world '
#     'of cocoa."',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 236 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     'so if people come asking :) ...You know.',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 238 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     'This should follow as well to social media.',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 240 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Emelin - Bahia',
#     'Always tell the benefits of being there and not saying "you can taste". '
#     'Just "you will taste"',
#     'Contributed Human Effort',
#     ' 0',
#     '20231026']
#
# Processing 242 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', 'Ok, now going to sleep', 'Unknown', ' 0', '20231026']
#
# Processing 244 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Val Lapidus',
#     'As far as I know no tickets necessary',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 246 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Emelin - Bahia',
#     'It is a wix thing. If it is paid or free they generate a ticket but there '
#     'says it is free just right away, I added to the title. I will look again '
#     'tomorrow how to drift this feature they have. They generate a ticket even '
#     'if it is free.',
#     'Contributed Human Effort',
#     ' 0',
#     '20231026']
#
# Processing 248 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', 'I will go further tomorrow.', 'Unknown', ' 0', '20231026']
#
# Processing 250 of 2021:
# 'Contributed Human Effort; 17'
# ['Contributed Human Effort', ' 17']
# 2
# [   'Emelin - Bahia',
#     'Thaaaaaaaanks Val',
#     'Contributed Human Effort',
#     ' 17',
#     '20231026']
#
# Processing 252 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     '@31641075825 uploaded recordings from today’s session \n'
#     '\n'
#     'https://drive.google.com/drive/folders/1202AoE7-XOPd5c_zM0ZFFGHsTz0YACZK',
#     'Contributed Human Effort',
#     ' 0',
#     '20231026']
#
# Processing 254 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Val Lapidus',
#     'How many new followers did we get today?',
#     'Unknown',
#     ' 0',
#     '20231026']
#
# Processing 256 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Val Lapidus',
#     'Our event was great everyone loved the hot chocolate and our CTA felt '
#     'like it resonated.  I covered three major points in my convos:\n'
#     '1.  Cabruca farming\n'
#     '2. 36% vs 6%\n'
#     '3.  Blockchain to document supply chain\n'
#     '\n'
#     'And closed with give us a follow on insta\n'
#     '\n'
#     'We met a reporter Rachel Wolfson who reports on web 3 projects and '
#     'hopefully we can nurture that relationship.',
#     'Contributed Human Effort',
#     ' 0',
#     '20231026']
#
# Processing 258 of 2021:
# 'Contributed Human Effort; 150 TDGs'
# ['Contributed Human Effort', ' 150 TDGs']
# 2
# [   'Val Lapidus',
#     'Spent 1.5 hours just now. Cleaning up after our cacao making exercise\n'
#     '\u200e',
#     'Contributed Human Effort',
#     ' 150 TDGs',
#     '20231026']
#
# Processing 260 of 2021:
# 'Contributed Human Effort; 400 TDGs'
# ['Contributed Human Effort', ' 400 TDGs']
# 2
# [   'Gary Teh',
#     'Me and @16468233438 spent 4 hours from 3pm to 7pm just now doing the '
#     'event at Edge and Node \n'
#     '\n'
#     '*Time taken: 4 hours*',
#     'Contributed Human Effort',
#     ' 400 TDGs',
#     '20231026']
#
# Processing 262 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Suheil - Europe', '+ 13', 'Unknown', ' 0', '20231027']
#
# Processing 264 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231027']
#
# Processing 266 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '@14153000019 perfect idea!', 'Unknown', ' 0', '20231027']
#
# Processing 268 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Val Lapidus',
#     "I'm about to send this to designer for a menu mockup:  please provide "
#     'feedback if you have some: '
#     'https://docs.google.com/document/d/1OT7Gn1k1GvPIpb4vUlC1CRtiygxvXpP6Nuznc2oSHsk/edit',
#     'Unknown',
#     ' 0',
#     '20231027']
#
# Processing 270 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     'What designer are you hiring? I have a recommendation of someone from '
#     'here.',
#     'Unknown',
#     ' 0',
#     '20231027']
#
# Processing 272 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Val Lapidus',
#     'i have a personal friend that does all the work for me',
#     'Unknown',
#     ' 0',
#     '20231027']
#
# Processing 274 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Val Lapidus',
#     'he is a contributor to the DAO',
#     'Contributed Human Effort',
#     ' 0',
#     '20231027']
#
# Processing 276 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Emelin - Bahia',
#     "Ok. In case he can't help, I have someone close to me as well.",
#     'Unknown',
#     ' 0',
#     '20231027']
#
# Processing 278 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', 'ty!', 'Unknown', ' 0', '20231027']
#
# Processing 280 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'Perhaps a profit share model with each event organizer.\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231027']
#
# Processing 282 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Val Lapidus',
#     'No profit share these types of events. Usually just have a flat fee\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20231027']
#
# Processing 284 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Val Lapidus',
#     "We don't want to profit share profit. Sharing is a worst case scenario "
#     'for us\n'
#     '\u200e',
#     'Contributed Human Effort',
#     ' 0',
#     '20231027']
#
# Processing 286 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Anupa/diya',
#     "Can't we use psd  mockups",
#     'Contributed Human Effort',
#     ' 0',
#     '20231027']
#
# Processing 288 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'Whatever drives conversion and 💵💶💷💴💴💸🤑 🤩🙏\n'
#     '\n'
#     '*Flat fee*\n'
#     'DAO bears the risk of both inventory and storefront \n'
#     '\n'
#     '*Profit share* \n'
#     'risk shared between event organizer and DAO. \n'
#     '\n'
#     '\n'
#     '*Profit share*\n'
#     'Seems more scalable since the only risk DAO bears is inventory risk which '
#     'we are bearing at cost\n'
#     '\n'
#     'Incentives are aligned\n'
#     '\n'
#     'Otherwise event organizers organize a shitty event and DAO paid for '
#     'shitty event \u200e<This message was edited>',
#     'Unknown',
#     ' 0',
#     '20231027']
#
# Processing 290 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Val Lapidus',
#     "I'm not sure what you're asking\n\u200e",
#     'Unknown',
#     ' 0',
#     '20231027']
#
# Processing 292 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Val Lapidus',
#     'The designer will create a PSD mocca',
#     'Contributed Human Effort',
#     ' 0',
#     '20231027']
#
# Processing 294 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', 'Mock up', 'Unknown', ' 0', '20231027']
#
# Processing 296 of 2021:
# 'Contributed Human Effort; 6TDG'
# ['Contributed Human Effort', ' 6TDG']
# 2
# ['Anupa/diya', 'OR canva', 'Contributed Human Effort', ' 6TDG', '20231027']
#
# Processing 298 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Anupa/diya', 'You get them free\n\u200e', 'Unknown', ' 0', '20231027']
#
# Processing 300 of 2021:
# 'Contributed Human Effort; 1'
# ['Contributed Human Effort', ' 1']
# 2
# [   'Anupa/diya',
#     'You just add the text\n\u200e',
#     'Contributed Human Effort',
#     ' 1',
#     '20231027']
#
# Processing 302 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Val Lapidus',
#     'We can figure out if an event is worthwhile by looking at it The risk '
#     "you're describing I don't think is valid",
#     'Unknown',
#     ' 0',
#     '20231027']
#
# Processing 304 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231027']
#
# Processing 306 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Val Lapidus',
#     'We should be targeting events that have decent venues that guarantee a '
#     'certain number of attendees. I think there are ways to mitigate this risk '
#     'by doing research on the event seeing past event participation, talking '
#     'to vendors who were at the event previously, things like that can '
#     'certainly mitigate the risk',
#     'Unknown',
#     ' 0',
#     '20231027']
#
# Processing 308 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'Let’s define an *event selection protocol* 🤩\n'
#     '\n'
#     'This can then be adopted into DAO standard operating procedure and ease '
#     'scaling later on\n'
#     '\n'
#     'Especially for inexperienced members attempting the same in new cities '
#     '\u200e<This message was edited>\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20231027']
#
# Processing 310 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231027']
#
# Processing 312 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted', 'Unknown', ' 0', '20231027']
#
# Processing 314 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231027']
#
# Processing 316 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231027']
#
# Processing 318 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231027']
#
# Processing 320 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231027']
#
# Processing 322 of 2021:
# 'Contributed Human Effort; 300'
# ['Contributed Human Effort', ' 300']
# 2
# [   'Val Lapidus',
#     "Gary and I spent 3 hours making hot cacao for tonight's event\n\u200e",
#     'Contributed Human Effort',
#     ' 300',
#     '20231027']
#
# Processing 324 of 2021:
# 'Contributed Human Effort; 200'
# ['Contributed Human Effort', ' 200']
# 2
# [   'Val Lapidus',
#     'I spent 2 hrs this morning shopping for the event\n\u200e',
#     'Contributed Human Effort',
#     ' 200',
#     '20231027']
#
# Processing 326 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Emelin - Bahia', 'Tree huggers?', 'Unknown', ' 0', '20231027']
#
# Processing 328 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'Very short form. 🤣\n'
#     '\n'
#     'People that are concerned about the environment and climate change \n'
#     '\n'
#     'There are lots of them here in California \u200e<This message was '
#     'edited>\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20231027']
#
# Processing 330 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Val Lapidus',
#     "there's also lots of flavors of them",
#     'Unknown',
#     ' 0',
#     '20231027']
#
# Processing 332 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     '@16468233438 recipe list you asked for\n'
#     '\n'
#     'https://docs.google.com/spreadsheets/d/19uHnJF7YJPCTbyxFUMZAC-TA-yGnYKWRwUKc3Is9xm0/edit',
#     'Contributed Human Effort',
#     ' 0',
#     '20231027']
#
# Processing 334 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted', 'Unknown', ' 0', '20231027']
#
# Processing 336 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '@5511982667030 or @16468233438 anyone want to follow up with Orlantildes '
#     'on the status of the 100kg shipment?\n'
#     '\n'
#     'It’s already Friday 🙂🙏\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20231027']
#
# Processing 338 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231027']
#
# Processing 340 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'Dead Farmers Sales Sheet Pod Foods.pdf • \u200e1 page \u200edocument '
#     'omitted',
#     'Unknown',
#     ' 0',
#     '20231027']
#
# Processing 342 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'co-brand flyer front v3 sm (1) (1).pdf • \u200e1 page \u200edocument '
#     'omitted',
#     'Unknown',
#     ' 0',
#     '20231027']
#
# Processing 344 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     'Reference material from Tres',
#     'Contributed Human Effort',
#     ' 0',
#     '20231027']
#
# Processing 346 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231027']
#
# Processing 348 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '@557191035605 and @557391090002 this question came up last night about '
#     'cabruca method \n'
#     '\n'
#     'How do we ensure we do not overpopulate the undergrowth of the canopy '
#     'with so much cacao trees it crowds out other species and decreases '
#     'biodiversity?\n'
#     '\n'
#     'Can you help provide answer?\n'
#     '\n'
#     'I am sure this question will come up again when we present in crowd who '
#     'are knowledgeable about environment and sustainability \n'
#     '\n'
#     'Thank you 🙂🙏 \u200e<This message was edited>',
#     'Unknown',
#     ' 0',
#     '20231028']
#
# Processing 350 of 2021:
# 'Contributed Human Effort; 12'
# ['Contributed Human Effort', ' 12']
# 2
# [   'Gary Teh',
#     '@5511982667030 and @16468233438 please help check status of 100kg '
#     'shipment on Monday \n'
#     '\n'
#     'Thank you 🙂🙏',
#     'Contributed Human Effort',
#     ' 12',
#     '20231028']
#
# Processing 352 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231028']
#
# Processing 354 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231028']
#
# Processing 356 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231028']
#
# Processing 358 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted', 'Unknown', ' 0', '20231028']
#
# Processing 360 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231028']
#
# Processing 362 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted', 'Unknown', ' 0', '20231028']
#
# Processing 364 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted', 'Unknown', ' 0', '20231028']
#
# Processing 366 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted', 'Unknown', ' 0', '20231028']
#
# Processing 368 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231028']
#
# Processing 370 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted', 'Unknown', ' 0', '20231028']
#
# Processing 372 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted', 'Unknown', ' 0', '20231028']
#
# Processing 374 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted', 'Unknown', ' 0', '20231028']
#
# Processing 376 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted', 'Unknown', ' 0', '20231028']
#
# Processing 378 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted', 'Unknown', ' 0', '20231028']
#
# Processing 380 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231028']
#
# Processing 382 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231028']
#
# Processing 384 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     '\u200eimage omitted\n\u200e',
#     'Contributed Human Effort',
#     ' 0',
#     '20231028']
#
# Processing 386 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231028']
#
# Processing 388 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted', 'Unknown', ' 0', '20231028']
#
# Processing 390 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted', 'Unknown', ' 0', '20231028']
#
# Processing 392 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted', 'Unknown', ' 0', '20231028']
#
# Processing 394 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted', 'Unknown', ' 0', '20231028']
#
# Processing 396 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted', 'Unknown', ' 0', '20231028']
#
# Processing 398 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231028']
#
# Processing 400 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231028']
#
# Processing 402 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231028']
#
# Processing 404 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231028']
#
# Processing 406 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Matheus Reis - Bahia Coop',
#     'As it is a shade-tolerant plant, it grows well in understories and thin '
#     'forests, making it an extremely conservationist crop for soil, fauna and '
#     'flora. Little mechanized, it is a culture that provides a high degree of '
#     'employment generation. It found in the south of Bahia one of the best '
#     'soils and climate for its expansion.\n'
#     '\n'
#     'The State of Bahia is the largest producer in Brazil, but its production '
#     "capacity was reduced by up to 60% with the advent of witches' broom, "
#     'caused by the phytopathogenic fungus Crinipellis perniciosa, currently '
#     'Moniliophthora perniciosa.\n'
#     '\n'
#     'The cocoa production system in Bahia is known as cabruca, an agroforestry '
#     'system, where the fruit is grown under trees in the Atlantic Forest, '
#     'having great importance for the preservation of the forest.\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20231028']
#
# Processing 408 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Matheus Reis - Bahia Coop',
#     'What does "lead content" means?',
#     'Unknown',
#     ' 0',
#     '20231028']
#
# Processing 410 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Val Lapidus',
#     'https://en.m.wikipedia.org/wiki/Lead\n'
#     '\n'
#     'Lead content is harmful to humans in large quantities and people often '
#     'are concerned about lead within their food',
#     'Unknown',
#     ' 0',
#     '20231028']
#
# Processing 412 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Matheus Reis - Bahia Coop',
#     "Oh! I see. I belive there isn't but I'll ask to be sure.",
#     'Unknown',
#     ' 0',
#     '20231028']
#
# Processing 414 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Anupa/diya',
#     'https://www.instagram.com/reel/CyvsmIsNsm4/?igshid=MzRlODBiNWFlZA==',
#     'Unknown',
#     ' 0',
#     '20231028']
#
# Processing 416 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Anupa/diya', 'I found these recipes', 'Unknown', ' 0', '20231028']
#
# Processing 418 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Anupa/diya',
#     '@16468233438 might be of some inspiration',
#     'Unknown',
#     ' 0',
#     '20231028']
#
# Processing 420 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231028']
#
# Processing 422 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231029']
#
# Processing 424 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     '\u200eYou deleted this message.',
#     'Contributed Human Effort',
#     ' 0',
#     '20231029']
#
# Processing 426 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231029']
#
# Processing 428 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200eYou deleted this message.\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231029']
#
# Processing 430 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200eYou deleted this message.\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231029']
#
# Processing 432 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231029']
#
# Processing 434 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200evideo omitted\n\u200e', 'Unknown', ' 0', '20231029']
#
# Processing 436 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Val Lapidus',
#     'Yes if shipment arrives',
#     'Contributed Human Effort',
#     ' 0',
#     '20231029']
#
# Processing 438 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     'Let’s have Victor do the paneling if he is open and keen\n'
#     '\n'
#     'He is a master orator. I seen him at it during WEF these past two time 🤩\n'
#     '\n'
#     'It’s quite hard to beat someone at orating when he is a full time '
#     'lecturer in Berkeley university 🤣\n'
#     '\n'
#     'Just like how @5511982667030 handled all the speaking the first time we '
#     'visited Coopercabruca at the trade association and the only thing I did '
#     'was show the ☮️✌️sign after she was done delivering her speech 🤣 '
#     '\u200e<This message was edited>',
#     'Contributed Human Effort',
#     ' 0',
#     '20231029']
#
# Processing 440 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Matheus Reis - Bahia Coop',
#     '\u200eimage omitted',
#     'Unknown',
#     ' 0',
#     '20231029']
#
# Processing 442 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', 'Yes!! 🙂🙏', 'Unknown', ' 0', '20231029']
#
# Processing 444 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231029']
#
# Processing 446 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231029']
#
# Processing 448 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231029']
#
# Processing 450 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231029']
#
# Processing 452 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231029']
#
# Processing 454 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231029']
#
# Processing 456 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231029']
#
# Processing 458 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'Dean is very thorough in terms of fact checking stuff',
#     'Unknown',
#     ' 0',
#     '20231029']
#
# Processing 460 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'Heads up \n'
#     '\n'
#     'Once our shipment of 100kg arrives my sixth sense tells me there is going '
#     'to be some transition in our guild member composition\n'
#     '\n'
#     'Folks who want to stay informed of our general progress can join the '
#     '@120363041505997891@g.us \n'
#     '\n'
#     'Folks who have enough voting rights to access our '
# ...
#     'Ok. Thanks. We need to be exact in forming prices and account for rising '
#     'costs. The more current and anticipatory info the better.',
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 1959 of 2021:
# 'Contributed Human Effort; 1'
# ['Contributed Human Effort', ' 1']
# 2
# [   'Vlatko Gigov',
#     '@31641075825 let me know about tomorrow. It’s important we dial in the '
#     'deck.',
#     'Contributed Human Effort',
#     ' 1',
#     '20231202']
#
# Processing 1960 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Val Lapidus',
#     "I don't know if there's a futures market for accountants, but you could "
#     "look at leaps if there are and see what they're prising. Pretend",
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 1961 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', 'Accountants I mean cacao nibs', 'Unknown', ' 0', '20231202']
#
# Processing 1962 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Vlatko Gigov',
#     'There is, but that’s at bulk. We are not there yet :)',
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 1963 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Vlatko Gigov',
#     'We can do hedge the min quantity we commit to purchase \u200e<This '
#     'message was edited>\n'
#     '\u200e',
#     'Contributed Human Effort',
#     ' 0',
#     '20231202']
#
# Processing 1964 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Vlatko Gigov',
#     '\u200e<attached: 00000371-VIDEO-2023-12-02-09-55-04.mp4>',
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 1965 of 2021:
# 'Contributed Human Effort; 1TDG'
# ['Contributed Human Effort', ' 1TDG']
# 2
# [   'Vlatko Gigov',
#     'Baby Jesus was pedalling for light.\n\u200e',
#     'Contributed Human Effort',
#     ' 1TDG',
#     '20231202']
#
# Processing 1966 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Vlatko Gigov',
#     '\u200e<attached: 00000373-VIDEO-2023-12-02-09-58-12.mp4>\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 1967 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200e<attached: 00000374-VIDEO-2023-12-02-10-56-32.mp4>',
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 1968 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Rodney Wieck',
#     'Yes, that is correct Val',
#     'Contributed Human Effort',
#     ' 0',
#     '20231202']
#
# Processing 1969 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Vlatko Gigov',
#     'Of Course, otherwise why are we disintegrating the supply (value) chain. '
#     'Please don’t think that the ppl in this org are only capitalists…',
#     'Contributed Human Effort',
#     ' 0',
#     '20231202']
#
# Processing 1970 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     'The most equitable approach would be for the commission pay out to be '
#     'done fully in TDG only. \n'
#     '\n'
#     'People who wants to cash out their TDG for fiat needs to go exchange them '
#     'at official venues \n'
#     '\n'
#     'Having a component in our comps that pays out Fiat directly to '
#     'participants undertaking any DAO related activity also sends out a *_very '
#     'negative signal*_ to people familiar with cryptocurrency tokenomics \n'
#     '\n'
#     'When I studied the tokenomics presented to me by Nio in Dubai (_*who does '
#     'pump and dump professionally*_) that is usually the back door he uses to '
#     'drain the fiat from any tokenomics system he comes up with\n'
#     '\n'
#     'And that is exactly how Ethan did it for his project wonderhero, another '
#     'mainland Chinese enabled *_pump and dump scheme*_ that took place in '
#     'Singapore \u200e<This message was edited>',
#     'Contributed Human Effort',
#     ' 0',
#     '20231202']
#
# Processing 1971 of 2021:
# 'Contributed Human Effort; 25'
# ['Contributed Human Effort', ' 25']
# 2
# [   'Gary Teh',
#     'I am open for the commission payout to be done in TDG \n'
#     '\n'
#     'And also for the commission payout formula that includes *_sales figure '
#     'secured_* and *_DAO standard rate*_\n'
#     '\n'
#     'Folks who are keen to crack their brains at it please feel free to '
#     'surface some formula for consideration \n'
#     '\n'
#     'And then have the formula submitted in our @120363111951279022@g.us for '
#     'voting 🙂🙏 \u200e<This message was edited>',
#     'Contributed Human Effort',
#     ' 25',
#     '20231202']
#
# Processing 1972 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Vlatko Gigov',
#     'Who is neo? Another Chinese induced capitalist scam.',
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 1973 of 2021:
# 'Contributed Human Effort; 100'
# ['Contributed Human Effort', ' 100']
# 2
# [   'Val Lapidus',
#     '1.  I agree tdg tokens as commission payment.\n2.',
#     'Contributed Human Effort',
#     ' 100',
#     '20231202']
#
# Processing 1974 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Vlatko Gigov',
#     'It’s not about what you are open',
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 1975 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Vlatko Gigov',
#     'It’s about what the value chain pertains',
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 1976 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Vlatko Gigov',
#     'We are not here to deal with your sentiment.',
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 1977 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Vlatko Gigov',
#     'WE ARE HERE TO DISINTEGRATE THE VALUE CHAIN',
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 1978 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     'We are here to deal with everybody’s sentiment via voting 🙂🙏',
#     'Contributed Human Effort',
#     ' 0',
#     '20231202']
#
# Processing 1979 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Vlatko Gigov', 'Nope', 'Unknown', ' 0', '20231202']
#
# Processing 1980 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Vlatko Gigov',
#     'We are here to exercise believe in doing',
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 1981 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Vlatko Gigov', 'GOOD', 'Unknown', ' 0', '20231202']
#
# Processing 1982 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'When we have consensus about how we can operate together then there is '
#     'disruption \n'
#     '\n'
#     'Otherwise don’t expect any action',
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 1983 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Val Lapidus',
#     'I think this conversation belongs in the beer hall',
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 1984 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Vlatko Gigov', 'Nope', 'Unknown', ' 0', '20231202']
#
# Processing 1985 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', 'True 🙂🙏', 'Unknown', ' 0', '20231202']
#
# Processing 1986 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Vlatko Gigov', 'It belongs to this activity', 'Unknown', ' 0', '20231202']
#
# Processing 1987 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Vlatko Gigov',
#     'As the one most prosperous to bring dollarz',
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 1988 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Val Lapidus',
#     "It's meta about this activity not specifically related to the activity",
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 1989 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Vlatko Gigov', 'Meta is bls', 'Unknown', ' 0', '20231202']
#
# Processing 1990 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Val Lapidus',
#     "Regardless, please don't dirty this thread with this nonsense and take it "
#     'into the beer hall',
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 1991 of 2021:
# 'Contributed Human Effort; 100TDG'
# ['Contributed Human Effort', ' 100TDG']
# 2
# [   'Gary Teh',
#     'Done with my break\n'
#     '\n'
#     'Back to meditation practice 🙂🙏\n'
#     '\n'
#     'Please feel free to jam on 1 and 2',
#     'Contributed Human Effort',
#     ' 100TDG',
#     '20231202']
#
# Processing 1992 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Vlatko Gigov', 'we haven’t moved from beta', 'Unknown', ' 0', '20231202']
#
# Processing 1993 of 2021:
# 'Contributed Human Effort; 60TDG'
# ['Contributed Human Effort', ' 60TDG']
# 2
# [   'Vlatko Gigov',
#     'we know what truesight stands for',
#     'Contributed Human Effort',
#     ' 60TDG',
#     '20231202']
#
# Processing 1994 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Vlatko Gigov', 'It’s in the name for gods sake', 'Unknown', ' 0', '20231202']
#
# Processing 1995 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Vlatko Gigov',
#     'I nor anyone else needs this. don’t think that the profits we generate '
#     'are going to help us individually',
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 1996 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Vlatko Gigov',
#     'We are here only to disintegrate',
#     'Contributed Human Effort',
#     ' 0',
#     '20231202']
#
# Processing 1997 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Vlatko Gigov', '👆', 'Unknown', ' 0', '20231202']
#
# Processing 1998 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Vlatko Gigov', 'maybe I’m wrong', 'Unknown', ' 0', '20231202']
#
# Processing 1999 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Val Lapidus',
#     'I want to point out that the margins on the possible commissions are not '
#     'all that high. Because our price is already high and compared to other '
#     'vendors, we need to be able to stay competitive while also offering a '
#     "feel good story.  And one more point, there's no reason that those of us "
#     "that are in developing countries can't do sales in the US or for that "
#     'matter. Any territory where we can import the product into and collect on '
#     'those commissions.  I think with a decent internet connection, you can '
#     'make phone calls into the US. Find vendors that you want to send the '
#     'sample to communicate with those vendors, get their address where to send '
#     'their sample and then ask me to send out the sample.',
#     'Contributed Human Effort',
#     ' 0',
#     '20231202']
#
# Processing 2000 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Val Lapidus',
#     'Everyone in this DAO can become part of the go-to market, and sell the '
#     'product',
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 2001 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Val Lapidus',
#     'And earn commission',
#     'Contributed Human Effort',
#     ' 0',
#     '20231202']
#
# Processing 2002 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Vlatko Gigov', 'I agree with you @16468233438', 'Unknown', ' 0', '20231202']
#
# Processing 2003 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Vlatko Gigov',
#     'So let’s map out the whole process in a nice % and value based timeline '
#     'to get everyone accounted for',
#     'Contributed Human Effort',
#     ' 0',
#     '20231202']
#
# Processing 2004 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Vlatko Gigov',
#     'Calling for an epistemological exercice in this inner circle',
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 2005 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Vlatko Gigov', 'D DAO is all about definitions.', 'Unknown', ' 0', '20231202']
#
# Processing 2006 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Vlatko Gigov',
#     'Maybe this is how we solve for inflation. Or maybe I am a communist',
#     'Unknown',
#     ' 0',
#     '20231202']
#
# Processing 2007 of 2021:
# 'Contributed Human Effort; 100TDG'
# ['Contributed Human Effort', ' 100TDG']
# 2
# [   'Gary Teh',
#     '*Parts required*\n'
#     '\n'
#     '1) verbal script that any DAO member can follow when telling Agroverse '
#     'story \n'
#     '\n'
#     '2) a protocol which they can follow in DAO to work the script',
#     'Contributed Human Effort',
#     ' 100TDG',
#     '20231202']
#
# Processing 2008 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     'For verbal script if someone want to come  up with an initial draft that '
#     'has been tested to work, that would be great.\n'
#     '\n'
#     'We can then modify this shared script as we use it to iterate with '
#     'prospective buyers 🙂🙏',
#     'Contributed Human Effort',
#     ' 0',
#     '20231203']
#
# Processing 2009 of 2021:
# 'Rubric classification: Contributed Human Effort; TDGs Issued: 0'
# ['Rubric classification: Contributed Human Effort', ' TDGs Issued: 0']
# 2
# [   'Gary Teh',
#     '*_Proposed compensation plan*_\n'
#     '\n'
#     '_Rationale_\n'
#     '    - incentivize DAO members to help make introductions \n'
#     '\n'
#     '    - utilizing existing 4 rules rubric based system without introductory '
#     'additional rules to rubric \n'
#     '\n'
#     '*_Meta Game Logic*_\n'
#     '    _Rule 1_ - full amount of first initial sale in USD from buyer '
#     'brought in by DAO, same exact amount is issued to DAO member who helped '
#     'made the sale in TDG\n'
#     '\n'
#     '    _Rule 2_ - the above amount is in addition to TDG awarded to DAO '
#     'member for hours spent bringing in the sale \n'
#     '\n'
#     '    _Rule 3_ - for subsequent sale by buyer, if buyer went directly to '
#     'DAO. DAO member who brought help brought in this buyer initially for sale '
#     'will not get any further TDG award based on sale amount\n'
#     '\n'
#     '    _Rule 4_ - for subsequent sale, if buyer had to utilize time of that '
#     'same DAO member before sale could happen (_making phone call_), TDG will '
#     'be still awarded for time spent by DAO member who is now playing the role '
#     'of the facilitator and not the sales person\n'
#     '\n'
#     '    _Rule 5_ - If DAO member has formed a separate company to buy from '
#     'DAO, that separate company is treated as a separate buyer. All prior '
#     'listed rules apply',
#     'Rubric classification: Contributed Human Effort',
#     ' TDGs Issued: 0',
#     '20231203']
#
# Processing 2010 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'https://www.bloomberg.com/news/newsletters/2023-12-01/chocolate-gets-pricier-as-cocoa-beans-in-west-africa-rot-from-climate-crisis\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20231210']
#
# Processing 2011 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200e<attached: 00000419-PHOTO-2023-12-11-12-13-46.jpg>\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231211']
#
# Processing 2012 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200e<attached: 00000420-PHOTO-2023-12-11-12-14-02.jpg>\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231211']
#
# Processing 2013 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Suheil - Europe',
#     '\u200e<attached: 00000421-GIF-2023-12-12-10-52-09.mp4>\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231212']
#
# Processing 2014 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200e<attached: 00000422-PHOTO-2023-12-12-11-06-17.jpg>',
#     'Unknown',
#     ' 0',
#     '20231212']
#
# Processing 2015 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200eYou deleted this message.\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231212']
#
# Processing 2016 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200e<attached: 00000424-PHOTO-2023-12-13-18-19-11.jpg>\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231213']
#
# Processing 2017 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200e<attached: 00000425-PHOTO-2023-12-13-18-19-12.jpg>\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231213']
#
# Processing 2018 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Val Lapidus',
#     '\u200e<attached: 00000426-PHOTO-2023-12-13-20-29-40.jpg>',
#     'Unknown',
#     ' 0',
#     '20231213']
#
# Processing 2019 of 2021:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Val Lapidus',
#     'Reaching out via Reddit to choclatiers\n\u200e',
#     'Contributed Human Effort',
#     ' 0',
#     '20231213']
#
# Processing 2020 of 2021:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200e<attached: 00000428-PHOTO-2023-12-13-23-56-16.jpg>',
#     'Unknown',
#     ' 0',
#     '20231213']

# %%
analysis_file.close()
