# %%
# Importing for system files
import os
import sys
import csv
import pprint

# %%
# Loading environmental variables 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Import System Files
dir_path = os.path.dirname(os.path.realpath('__file__'))
sys.path.append(dir_path + '/lib/')  
from process_work import process_work

# %%
# For processing WhatsApp data file
from whatstk import df_from_txt_whatsapp
from whatstk.data import whatsapp_urls

# %%
# File key
file_key = '20231213_beerhall_chat'

# %%
# Importing WhatsApp data file
df = df_from_txt_whatsapp(filepath=f"./data/{file_key}.txt")
df.head(100)

# Setup work analysis file
analysis_file = open(f"analysis/{file_key}.csv", 'w')
analysis_writer = csv.writer(analysis_file)

header = ['Contributor Name', 'Contribution Made', 'Rubric classification', 'TDGs Issued', 'Status date']
# data = ['Afghanistan', 652090, 'AF', 'AFG']
analysis_writer.writerow(header)

pp = pprint.PrettyPrinter(indent=4)

# %%
# For OpenAI client
from openai import OpenAI

# Acquire OpenAI API Key via this URL 
#    https://platform.openai.com/api-keys
# Save Secret in .env file with 
#    OPENAI_API_KEY=YOUR SECRET KEY

openai_client = OpenAI(
    # This is the default and can be omitted
    api_key=os.environ.get("OPENAI_API_KEY"),
)

# %%
total_rows = df.count()['date']

# %%
# Calling OpenAi API to get time taken for work done
def check_tdg_issued(work_description):
    payload = f"We award 100TDG for every hour of contribution made that was explicitly reported in the Action Description. \
                We award 1.666666666666667TDG for every minute of contribution made that was explicitly reported in the Action Description. \
                 Amount of TDG issued should be prorated based on actual time explicitly reported\
                 Time taken indicated in the 'Action Description' may also appear in the following formats as a stand alone sentences\
                     Time Taken : X Hours \
                     Time Taken : Y Minutes \
                     \
                 We award 1TDG for each USD of expenses paid for onbehalf by DAO member \
                 There are only two available options for 'Rubric classification' and they are: \
                     'Contributed Fiat Funding' \
                     'Contributed Human Effort' \
                     \
                 Response must be short and concise\
                 Response must be in a single line CSV format. Response must not include headers\
                     Rubric classification (String); TDGs Issued (Integer)\
                     \
                 If Action Description does not make sense return the following values \
                     Unknown; 0 \
                     \
                 For the following 'Action Description' determine Rubric classification and TDGs Issued \
                     \
                 Action Description:\
                 {work_description}."
    
    work_process_completion = openai_client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": payload,
            }
        ],
        model="gpt-3.5-turbo",
    )
    return work_process_completion.choices[0].message.content

# response = check_tdg_issued("Gary Teh walked the dog for 1 hour")

# %%
for index, row in df.iterrows():
    clean_work_description = row['message'].encode('ascii','ignore') 
    response = check_tdg_issued(clean_work_description)
    openai_result = response.split(';')
    
    classification = "Unknown"
    tdg_issue = 0
    
    if len(openai_result) == 2:
        classification = openai_result[0]
        tdg_issue = openai_result[1]

    format = '%Y%m%d'

    # header = ['Contributor Name', 'Contribution Made', 'Rubric classification', 'TDGs Issued', 'Status date']
    data = [
        row['username'], 
        row['message'], 
        classification, 
        tdg_issue, 
        row['date'].strftime(format)
    ]
    print("")
    print(f"Processing {index} of {total_rows}: ")
    pp.pprint(response)
    pp.pprint(openai_result)
    pp.pprint(len(openai_result))
    pp.pprint(data)
    
    
    analysis_writer.writerow(data)
# Out:
# Processing 0 of 513:
# 'Contributed Human Effort; 400'
# ['Contributed Human Effort', ' 400']
# 2
# [   'Gary Teh',
#     '*Tokenization completion event - 20231107*\n\nTime taken: 4 hours',
#     'Contributed Human Effort',
#     ' 400',
#     '20231107']
#
# Processing 1 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     'They used the trade of cacao to dominate and establish their empires '
#     '.....\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20230808']
#
# Processing 2 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231107']
#
# Processing 3 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     "Getting the cacao meant power it didn't grow in the region.....\n\u200e",
#     'Unknown',
#     ' 0',
#     '20230808']
#
# Processing 4 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231107']
#
# Processing 5 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     'In realation to price , both cultures had store houses and cacao was '
#     'prepared in the "God house"\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20230808']
#
# Processing 6 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231107']
#
# Processing 7 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Tres Garcia', '\u200eTres Garcia left\n\u200e', 'Unknown', ' 0', '20230808']
#
# Processing 8 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231107']
#
# Processing 9 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Tess walkowski', '\u200eimage omitted', 'Unknown', ' 0', '20230808']
#
# Processing 10 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eYou deleted this message.', 'Unknown', ' 0', '20231107']
#
# Processing 11 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Tess walkowski', '10 for a rabbit', 'Unknown', ' 0', '20230808']
#
# Processing 12 of 513:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     '\u200eYou deleted this message.',
#     'Contributed Human Effort',
#     ' 0',
#     '20231107']
#
# Processing 13 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Tess walkowski', '40-60 beans a fruit\n\u200e', 'Unknown', ' 0', '20230808']
#
# Processing 14 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231108']
#
# Processing 15 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     '2 cacao pod for a slave.....\n\u200e',
#     'Unknown',
#     ' 0',
#     '20230808']
#
# Processing 16 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231108']
#
# Processing 17 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Tess walkowski', 'Wow\n\u200e', 'Unknown', ' 0', '20230808']
#
# Processing 18 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231108']
#
# Processing 19 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200evideo omitted', 'Unknown', ' 0', '20230808']
#
# Processing 20 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Dr. Denis',
#     'Ann-Marie is great! They are part of www.sora.org ecosystem. Phygital NFT '
#     'linked to real bottles of wine has a big potential, especially when it '
#     'comes to rare collectible wines',
#     'Unknown',
#     ' 0',
#     '20231108']
#
# Processing 21 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Tess walkowski', 'More criolla', 'Unknown', ' 0', '20230808']
#
# Processing 22 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Val Lapidus',
#     "This is one of those things where it's going to get lost in the shuffle.  "
#     'But we really need this. This is why slack is a much better way to do '
#     'these types of communications right now. This requires that somebody '
#     'memorizes that this contact and thread exists',
#     'Unknown',
#     ' 0',
#     '20231108']
#
# Processing 23 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     "I've been high all week\n\u200e",
#     'Unknown',
#     ' 0',
#     '20230808']
#
# Processing 24 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231108']
#
# Processing 25 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     'FYI Peru has known issues....with sourcing',
#     'Unknown',
#     ' 0',
#     '20230808']
#
# Processing 26 of 513:
# 'Contributed Human Effort; 120TDG'
# ['Contributed Human Effort', ' 120TDG']
# 2
# [   'Gary Teh',
#     '@918017107841 has recently exercised her *autonomy* to create a new Wix '
#     'based website for our main community site at TrueSight.me as Shadi has '
#     'been busy with work and couldn’t find time to continue building out the '
#     'Wordpress based community site \n'
#     '\n'
#     'I think her efforts at exercising her *autonomy* to creatively solve a '
#     'problem was commendable 🙂🙏',
#     'Contributed Human Effort',
#     ' 120TDG',
#     '20231108']
#
# Processing 27 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     'Much like in the Mayans skimping on quality and mixing orgin beans with '
#     'sad beans was a thing',
#     'Unknown',
#     ' 0',
#     '20230808']
#
# Processing 28 of 513:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     'From my perspective, more of these *autonomous* actions are beneficial '
#     'for our DAO and also encourages *Diversity* within our ecosystem \n'
#     '\n'
#     '*Diversity* is one of our core values',
#     'Contributed Human Effort',
#     ' 0',
#     '20231108']
#
# Processing 29 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Tess walkowski', 'Which is your favorite', 'Unknown', ' 0', '20230808']
#
# Processing 30 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'Coopercabruca publishes this post about our shipment \n'
#     '\n'
#     'https://www.instagram.com/p/CzYiCqZOWKn/?igshid=Y2NkYjk0MDhjYg==',
#     'Unknown',
#     ' 0',
#     '20231108']
#
# Processing 31 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'I might be biased but it still default to our Brazilian cacao nibs\n'
#     'I sampled some Ecuadorian pallets a few week ends ago. Those were really '
#     'really smooth. Right on the other end of the acidity spectrum.\n'
#     '\n'
#     'Also we need to ensure the packaging has aluminum lining on the inside of '
#     'the packaging otherwise the plastic taste is just going to ruin the taste '
#     'of the cacao nibs. And make it taste 🤮\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20230808']
#
# Processing 32 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231108']
#
# Processing 33 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20230808']
#
# Processing 34 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231108']
#
# Processing 35 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20230808']
#
# Processing 36 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231108']
#
# Processing 37 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20230808']
#
# Processing 38 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231108']
#
# Processing 39 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     'What did you choose for a labeling solution\n\u200e',
#     'Unknown',
#     ' 0',
#     '20230808']
#
# Processing 40 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231108']
#
# Processing 41 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Tess walkowski', '\u200evideo omitted\n\u200e', 'Unknown', ' 0', '20230808']
#
# Processing 42 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231108']
#
# Processing 43 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     "I'm so happy but I might just be high on cacao\n\u200e",
#     'Unknown',
#     ' 0',
#     '20230808']
#
# Processing 44 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231108']
#
# Processing 45 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     'How cool we do this same time\n\u200e',
#     'Unknown',
#     ' 0',
#     '20230808']
#
# Processing 46 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231108']
#
# Processing 47 of 513:
# 'Contributed Human Effort; 100'
# ['Contributed Human Effort', ' 100']
# 2
# [   'Gary Teh',
#     'https://www.linkedin.com/posts/bbalfour_stand-ups-are-the-dumbest-thing-weve-done-activity-7094707885204508672-I-gw?utm_source=share&utm_medium=member_ios\n'
#     '\n'
#     'Makes total sense everytime we call an hour meetup where we have a whole '
#     'bunch of attendees with no clear relationship as why they are attending '
#     'and how the presence is related to the agenda, we are wasting 100 '
#     'governance tokens from our very limited supply for each person per hour.',
#     'Contributed Human Effort',
#     ' 100',
#     '20230808']
#
# Processing 48 of 513:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     '@918017107841 once you have the new site ready with the onboarding flow  '
#     'in place, let’s schedule a session to demonstrate it to Hans Martin\n'
#     '\n'
#     'It’s perfect for what he described yesterday \n'
#     '\n'
#     'Also Micheal from Peace on Snow was originally surfaced by @33652866472 '
#     'as someone whom we should talk to for our Swiss Association needs as '
#     'Peace on Snow is a Swiss association \n'
#     '\n'
#     'My original intention when I reached out earlier in the year was to '
#     'figure out how to tap into that piece of infrastructure. I did not get '
#     'any response then\n'
#     '\n'
#     'But seems like the universe got everything ready and presented it on a '
#     'silver platter for us \n'
#     '\n'
#     'If implemented properly Hans Martin will end up onboarding the entire '
#     'Davos community on to the platform \n'
#     '\n'
#     'What a match made in heaven!! 🤩 \u200e<This message was edited>',
#     'Contributed Human Effort',
#     ' 0',
#     '20231108']
#
# Processing 49 of 513:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     'We printed using @16468233438 printer',
#     'Contributed Human Effort',
#     ' 0',
#     '20230808']
#
# Processing 50 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '@31641075825 did @972543523823 made this video clip?\n'
#     '\n'
#     'It is so beautifully made 🤩🙏\n'
#     '\n'
#     'https://www.instagram.com/reel/CzZdx3Qo_tW/?igshid=MTVtemoxb2I5ZDhlag==',
#     'Unknown',
#     ' 0',
#     '20231108']
#
# Processing 51 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Tess walkowski', 'Looks awesome!', 'Unknown', ' 0', '20230808']
#
# Processing 52 of 513:
# 'Contributed Human Effort; 40TDG'
# ['Contributed Human Effort', ' 40TDG']
# 2
# [   'Gary Teh',
#     'Please let us know how much time @972543523823 spent to create this and '
#     'how much time you spent to post it 🙂🙏',
#     'Contributed Human Effort',
#     ' 40TDG',
#     '20231108']
#
# Processing 53 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     'We do a lot in these groups. How we talk now.\n\u200e',
#     'Unknown',
#     ' 0',
#     '20230808']
#
# Processing 54 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231108']
#
# Processing 55 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Tess walkowski', 'Cacao was currency\n\u200e', 'Unknown', ' 0', '20230808']
#
# Processing 56 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231108']
#
# Processing 57 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     'People are reaching out. Venelualians. Ghanians.',
#     'Unknown',
#     ' 0',
#     '20230808']
#
# Processing 58 of 513:
# 'Contributed Human Effort; 200TDGs'
# ['Contributed Human Effort', ' 200TDGs']
# 2
# [   'Suheil - Europe',
#     '2 hours for @972543523823',
#     'Contributed Human Effort',
#     ' 200TDGs',
#     '20231109']
#
# Processing 59 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     'I\'m over here becoming a cacao "shaman" but I\'m so glad to have this '
#     "dao. I want to change the world. I need y'all. 🙏\n"
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20230808']
#
# Processing 60 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231109']
#
# Processing 61 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20230808']
#
# Processing 62 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231109']
#
# Processing 63 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20230808']
#
# Processing 64 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231109']
#
# Processing 65 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20230808']
#
# Processing 66 of 513:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     'Speaking of Lisbon… what a coincidence! \n'
#     '\n'
#     'Most popular destination for our IRL meetup was Lisbon 🤩 \u200e<This '
#     'message was edited>\n'
#     '\u200e',
#     'Contributed Human Effort',
#     ' 0',
#     '20231109']
#
# Processing 67 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20230808']
#
# Processing 68 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Suheil - Europe',
#     'huuuh???? lets take a batch from it then! hhhhh i wish it was possible '
#     'that woulldve been perfect !',
#     'Unknown',
#     ' 0',
#     '20231109']
#
# Processing 69 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   '\u202a+33\xa06\xa074\xa035\xa048\xa039\u202c',
#     '\u200e\u202a+33\xa06\xa074\xa035\xa048\xa039\u202c left',
#     'Unknown',
#     ' 0',
#     '20230809']
#
# Processing 70 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Suheil - Europe',
#     'daaaaamn i wanted 5 responses oon 1 city to go ahead hhh but yoou know '
#     'what… LFG lets do iit!!!',
#     'Unknown',
#     ' 0',
#     '20231109']
#
# Processing 71 of 513:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Tess walkowski',
#     "Cool I'll order it\n\u200e",
#     'Contributed Human Effort',
#     ' 0',
#     '20230809']
#
# Processing 72 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231109']
#
# Processing 73 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     'Honestly eagerly awaiting when they release the codex In print next year\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20230809']
#
# Processing 74 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eGIF omitted', 'Unknown', ' 0', '20231109']
#
# Processing 75 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     "I need academic access lol for cacao it's",
#     'Unknown',
#     ' 0',
#     '20230809']
#
# Processing 76 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Suheil - Europe',
#     '\u200ePOLL:\n'
#     'Lisbon IRL meet up NOVEMBER\n'
#     '\u200eOPTION: During the week 12th (0 votes)\n'
#     '\u200eOPTION: week end of 16th (0 votes)\n'
#     '\u200eOPTION: During the week 19th (0 votes)\n'
#     '\u200eOPTION: Week end of 24th (0 votes)',
#     'Unknown',
#     ' 0',
#     '20231109']
#
# Processing 77 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     "I think it's the Dresden codex I forget it's name",
#     'Unknown',
#     ' 0',
#     '20230809']
#
# Processing 78 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'Our cacao is arriving in SF on the 16th by the way 🤩 \u200e<This message '
#     'was edited>\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20231109']
#
# Processing 79 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20230810']
#
# Processing 80 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Suheil - Europe', 'dammn', 'Unknown', ' 0', '20231109']
#
# Processing 81 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eYou deleted this message.', 'Unknown', ' 0', '20230810']
#
# Processing 82 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200eYou deleted this message.\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231109']
#
# Processing 83 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20230810']
#
# Processing 84 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231109']
#
# Processing 85 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20230810']
#
# Processing 86 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Ken Nim - Bay Area ',
#     '@16468233438 @14153000019 , can you send some pics sans quick write up '
#     'you want me to use to post on LinkedIn and Twitter to thank you and '
#     'promote the product? Thanks.',
#     'Unknown',
#     ' 0',
#     '20231109']
#
# Processing 87 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Tess walkowski', 'Did you say Venezuela\n\u200e', 'Unknown', ' 0', '20230810']
#
# Processing 88 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231109']
#
# Processing 89 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Tess walkowski', "I'm on a plane .... :)", 'Unknown', ' 0', '20230810']
#
# Processing 90 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Ken Nim - Bay Area ',
#     'Was thinking of a photo from the event, but I can use that',
#     'Unknown',
#     ' 0',
#     '20231109']
#
# Processing 91 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     'My friend sent me a text a gorgeous meme begging me to think of '
#     'venelualia\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20230810']
#
# Processing 92 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231109']
#
# Processing 93 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     'And one of the most inspirational cases is from there a competitor who '
#     'succeeded\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20230810']
#
# Processing 94 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231109']
#
# Processing 95 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     "It's gonna have the world's best like Colombia",
#     'Unknown',
#     ' 0',
#     '20230810']
#
# Processing 96 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Ken Nim - Bay Area ',
#     'https://twitter.com/offchainglobal/status/1722759101908988125?s=61&t=jx5TfvIVDDh8ZASBJ9lRnw',
#     'Unknown',
#     ' 0',
#     '20231109']
#
# Processing 97 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     'But their people suffer more and need help. I am all hand on deck for '
#     'venelualia.',
#     'Unknown',
#     ' 0',
#     '20230810']
#
# Processing 98 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Ken Nim - Bay Area ',
#     'https://www.linkedin.com/feed/update/urn:li:activity:7126614503693197312?commentUrn=urn%3Ali%3Acomment%3A%28activity%3A7126614503693197312%2C7128524497632034818%29&dashCommentUrn=urn%3Ali%3Afsd_comment%3A%287128524497632034818%2Curn%3Ali%3Aactivity%3A7126614503693197312%29',
#     'Unknown',
#     ' 0',
#     '20231109']
#
# Processing 99 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Tess walkowski', 'Well and Brasil too bc ....', 'Unknown', ' 0', '20230810']
#
# Processing 100 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'Very cool! Thank you for sharing about the project @14152032783 🙂🙏\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20231109']
#
# Processing 101 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Tess walkowski', '\u200eimage omitted', 'Unknown', ' 0', '20230810']
#
# Processing 102 of 513:
# 'Contributed Human Effort; 16'
# ['Contributed Human Effort', ' 16']
# 2
# [   'Gary Teh',
#     'I just replied to both of them! 🤩🙏\n\n*Time taken: 10 minutes*',
#     'Contributed Human Effort',
#     ' 16',
#     '20231109']
#
# Processing 103 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tomas - Offchain',
#     "On the things that I'm writing now I got to the point that it is better "
#     'to talk about value than wealth. Gives more room to talk.',
#     'Unknown',
#     ' 0',
#     '20230810']
#
# Processing 104 of 513:
# 'Contributed Human Effort; 8'
# ['Contributed Human Effort', ' 8']
# 2
# [   'Gary Teh',
#     '@19514467219 found and just shared another retailer selling special '
#     'mushroom 🤩\n'
#     '\n'
#     'https://xenses.us/\n'
#     '\n'
#     '*Time taken: 5 minutes*',
#     'Contributed Human Effort',
#     ' 8',
#     '20231109']
#
# Processing 105 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     '\u200eThis message was deleted.\n\u200e',
#     'Unknown',
#     ' 0',
#     '20230810']
#
# Processing 106 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231109']
#
# Processing 107 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     'This concept is integral to our website to our presentation\n\u200e',
#     'Unknown',
#     ' 0',
#     '20230810']
#
# Processing 108 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231109']
#
# Processing 109 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20230810']
#
# Processing 110 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231109']
#
# Processing 111 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     'It would probably do that with heat',
#     'Unknown',
#     ' 0',
#     '20230810']
#
# Processing 112 of 513:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     'Based on this paradigm, all these socializing I have been doing at '
#     '*various networking events* these past few weeks is basically '
#     '*fundraising* of the non-fiat kind 🤔🤯🤣',
#     'Contributed Human Effort',
#     ' 0',
#     '20231109']
#
# Processing 113 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     'The butter separate when I overbook and chill\n\u200e',
#     'Unknown',
#     ' 0',
#     '20230810']
#
# Processing 114 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231109']
#
# Processing 115 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20230810']
#
# Processing 116 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231109']
#
# Processing 117 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'https://theconversation.com/what-the-npc-streaming-tiktok-trend-spells-for-the-future-of-gaming-and-erotic-work-210257?fbclid=IwAR1AE42Z3fApU_ARLwK1Wk0mINCadUeFWCQguSRm_Cq8PJCsP0KbISi1MJ8_aem_AXKlItBFOYcdgSoLU1mGOi8WsyYEQUr_MLm1934zx4ExYZt7MWYCUNlL67nxMTsuJNE\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20230810']
#
# Processing 118 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231109']
#
# Processing 119 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200eYou deleted this message.\n\u200e',
#     'Unknown',
#     ' 0',
#     '20230810']
#
# Processing 120 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eGIF omitted\n\u200e', 'Unknown', ' 0', '20231109']
#
# Processing 121 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20230810']
#
# Processing 122 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', 'Bump', 'Unknown', ' 0', '20231109']
#
# Processing 123 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'Allison says to look at independent mum and pop organic markets in the '
#     'Bay Area\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20230810']
#
# Processing 124 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231109']
#
# Processing 125 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'Regarding our SunMint project Allison mentioned she will start looking '
#     'into implementing solid state servers with zero moving parts. The '
#     'challenge for her would be to keep the cost under USD1000\n'
#     '\n'
#     'Those servers should theoretically run forever when deployed on the '
#     'farmers’ premises \n'
#     '\n'
#     'Since we are considering the use of Proof of Authority for TrueChain, '
#     'they should not cause too much heat generation \n'
#     '\n'
#     'Was chatting this afternoon with @16468233438 about running some '
#     'stand-alone nodes using solar panels out of his storage shed, just for '
#     'experimentation sake… actually more for the fun of it 🤣\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20230810']
#
# Processing 126 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231109']
#
# Processing 127 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Val Lapidus', 'Did you play poker?', 'Unknown', ' 0', '20230810']
#
# Processing 128 of 513:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     '@31641075825 once Hans Martin replies we should reach out to Alex from '
#     'OVH to unlock some cloud hosting resources 🤩🙏 \u200e<This message was '
#     'edited>',
#     'Contributed Human Effort',
#     ' 0',
#     '20231109']
#
# Processing 129 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'Nope. We just had dinner and some discussions about random topics. She '
#     'says they are moving to the new office at downtown San Mateo next month\n'
#     '\n'
#     'It would be pretty Boomz that we all catch up for poker at some point. 👊\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20230810']
#
# Processing 130 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231109']
#
# Processing 131 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'interesting how Jerry immediately homed in on the zero accountability '
#     'characteristic that’s been baked right into the DNA of the DAO that Cindy '
#     '(whom you introduced last year) pointed out when she was looking into our '
#     'structure last year which from her perspective is disconcerting to '
#     'traditional investors',
#     'Unknown',
#     ' 0',
#     '20230810']
#
# Processing 132 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'Let’s get his and Micheal’s feedback \n'
#     '\n'
#     'If they feel receptive enough about it then we can trail tested it',
#     'Unknown',
#     ' 0',
#     '20231109']
#
# Processing 133 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'After Jerry left for home, me and Allison stuck around for a short bit '
#     'where we chat about our tendency to keep injecting entropy into the '
#     'system whenever we observe it on the cusp of achieving some form of '
#     'equilibrium. Basically a dissipative structure \n'
#     '\n'
#     'https://en.wikipedia.org/wiki/Dissipative_system',
#     'Unknown',
#     ' 0',
#     '20230810']
#
# Processing 134 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'I have shared that we are transitioning to this new  _4 rule rubric '
#     'system_ with the core team at the *House of Balance*. (Hans Martin '
#     'originally invited me to that group because they were keen to replicate '
#     'the system we have in place back last year.)\n'
#     '\n'
#     'They seem receptive to it. we were trying to implement a variant of our '
#     '_legacy rubric system_ in *House of Balance* over the past 12 months. \n'
#     '\n'
#     'Unfortunately, the need for a dedicated _accountant/subjective judge_ in '
#     'the legacy rubric system was too much of an overhead and it didn’t really '
#     'scale well as I got dragged into the operations side of things in '
#     '@120363044028036610@g.us \n'
#     '\n'
#     'Once we have trialed tested this new *4 rules rubric system* in both '
#     '_TrueSight DAO_ and _Peace on Snow_ and it shows to work, we can arrange '
#     'a session to do a mini-trial with the House of Balance folks as well. \n'
#     '\n'
#     'If it works when rolled out to the *House of Balance* then we could '
#     'basically roll it out to all the other communities attempting to pursue '
#     'social enterprises as the core of their DNA but hampered with limited '
#     'ability to gather fiat funding for their needs 🤔\n'
#     '\n'
#     'Just some random ideas to popped into my mind just now 🤷\u200d♂️🤣 '
#     '\u200e<This message was edited>',
#     'Unknown',
#     ' 0',
#     '20231109']
#
# Processing 135 of 513:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     'Jerry was joking about the human mechanical Turk where AI defines the '
#     'strategy and humans perform the offline action \n'
#     '\n'
#     'Taking a step back and looking at where we are heading it does feel like '
#     'our DAO is slowly headed in that general direction with the introduction '
#     'of ChatGpt as the unofficial member which gets utilized a lot in the '
#     'background\n'
#     '\u200e',
#     'Contributed Human Effort',
#     ' 0',
#     '20230810']
#
# Processing 136 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231109']
#
# Processing 137 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20230811']
#
# Processing 138 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231109']
#
# Processing 139 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20230811']
#
# Processing 140 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200eYou deleted this message.\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231109']
#
# Processing 141 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20230811']
#
# Processing 142 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231109']
#
# Processing 143 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20230811']
#
# Processing 144 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231109']
#
# Processing 145 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20230811']
#
# Processing 146 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231109']
#
# Processing 147 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20230811']
#
# Processing 148 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231109']
#
# Processing 149 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20230811']
#
# Processing 150 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231109']
#
# Processing 151 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Tess walkowski', 'Neo eats fat bomb', 'Unknown', ' 0', '20230811']
#
# Processing 152 of 513:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     '\u200eYou deleted this message.',
#     'Contributed Human Effort',
#     ' 0',
#     '20231110']
#
# Processing 153 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Tess walkowski', 'Smith gone', 'Unknown', ' 0', '20230811']
#
# Processing 154 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eYou deleted this message.', 'Unknown', ' 0', '20231110']
#
# Processing 155 of 513:
# 'Contributed Human Effort; 76'
# ['Contributed Human Effort', ' 76']
# 2
# [   'Tess walkowski',
#     'Beer hall, group, can you get me venelualian/ Colombian criolla through '
#     'our channels.  Must be neo. Must be ready. Stay agile.',
#     'Contributed Human Effort',
#     ' 76',
#     '20230811']
#
# Processing 156 of 513:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     'Angeline just surfaced another company in the same category \n'
#     '\n'
#     'GoldenDoorChocolate',
#     'Contributed Human Effort',
#     ' 0',
#     '20231110']
#
# Processing 157 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'https://www.cnn.com/us/live-news/hawaii-maui-wildfires-08-11-23/index.html\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20230811']
#
# Processing 158 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231110']
#
# Processing 159 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     "What's going on in Africa\n\u200e",
#     'Unknown',
#     ' 0',
#     '20230811']
#
# Processing 160 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231110']
#
# Processing 161 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Tess walkowski',
#     'I just heard something I need to analyze world news\n\u200e',
#     'Unknown',
#     ' 0',
#     '20230811']
#
# Processing 162 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231110']
#
# Processing 163 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', 'End of the world is happening 😱', 'Unknown', ' 0', '20230811']
#
# Processing 164 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Iwona Fluda',
#     'The question is if they were warned about next steps/ if they were aware '
#     'of this possibility. If not, I fully understand them. \n'
#     '\n'
#     'I understand that it sometimes seems that we live in a “cancel culture”, '
#     'but I totally don’t get why we shouldn’t act differently individually and '
#     'collectively. - just a thought. \u200e<This message was edited>',
#     'Unknown',
#     ' 0',
#     '20231110']
#
# Processing 165 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Karin - no excuses LANUR Davos',
#     'does Edgar agree. Does it reflect the truth, or are the reports being '
#     'exaggerated just to provide entertainment for the Western world and '
#     'distract them from their own problems?',
#     'Unknown',
#     ' 0',
#     '20230812']
#
# Processing 166 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'They probably thought the rules that were voted into our '
#     'constitution/white paper did not apply to them or thought they could '
#     'probably get away with breaking rules once these have been voted into '
#     'place \n'
#     '\n'
#     'Or they came into the ecosystem before those ruled were put in place and '
#     'did not bother to keep abreast of rule changes that have been voted into '
#     'effect \n'
#     '\n'
#     'The folks that stuck around modified their behavior to fit the rules once '
#     'informed \n'
#     '\n'
#     'Those that left because they suddenly realized there was no more value to '
#     'be derived and there was nothing they want to contribute in the first '
#     'place. They were just in here for sales lead generation to power their '
#     'own business models. \n'
#     '\n'
#     'They opted to leave. Though we do have a three strikes and you are out '
#     'policy. They did not even get to strike 2 \u200e<This message was edited>',
#     'Unknown',
#     ' 0',
#     '20231110']
#
# Processing 167 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Alessandro Mele',
#     'Maybe you should test them blindfolded to avoid bias ?',
#     'Unknown',
#     ' 0',
#     '20230812']
#
# Processing 168 of 513:
# 'Contributed Human Effort; 76'
# ['Contributed Human Effort', ' 76']
# 2
# [   'Iwona Fluda',
#     'So the question is to all of us: Do you read all the terms and conditions '
#     'when you join a group of people?',
#     'Contributed Human Effort',
#     ' 76',
#     '20231110']
#
# Processing 169 of 513:
# 'Contributed Human Effort; 5TDG'
# ['Contributed Human Effort', ' 5TDG']
# 2
# [   'Gary Teh',
#     'Yup. We are just going to put the samples in small bowls labeled 1-5',
#     'Contributed Human Effort',
#     ' 5TDG',
#     '20230812']
#
# Processing 170 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'That is a very good question 🤣\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231110']
#
# Processing 171 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20230812']
#
# Processing 172 of 513:
# "'Unknown; 0'"
# ["'Unknown", " 0'"]
# 2
# [   'Iwona Fluda',
#     'When we talk about strikes: which rules did I break that it caused me '
#     'being kicked out of the Agroverse Guilt without warning?\n'
#     '\u200e',
#     "'Unknown",
#     " 0'",
#     '20231110']
#
# Processing 173 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20230812']
#
# Processing 174 of 513:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     'Notice how the trickle in of folks in our channels have slowed recently?\n'
#     '\n'
#     'I started requiring prospects keen to join our channels to read our white '
#     'paper to understand our rules first',
#     'Contributed Human Effort',
#     ' 0',
#     '20231110']
#
# Processing 175 of 513:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Fatima',
#     'Interesting that “climate change” doesn’t appear at all.',
#     'Contributed Human Effort',
#     ' 0',
#     '20230812']
#
# Processing 176 of 513:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     'You were not being kicked out but rotated out \n'
#     '\n'
#     'The guild have a different set of rules that were voted in  \n'
#     '\n'
#     'A maximum capacity of 8\n'
#     '\n'
#     'When a new active members need to join, the least active is invited out \n'
#     '\n'
#     'All the other seven were active on some ongoing tasks \u200e<This message '
#     'was edited>',
#     'Contributed Human Effort',
#     ' 0',
#     '20231110']
#
# Processing 177 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'Not catchy enough to make it to the top 100 most popular keywords',
#     'Unknown',
#     ' 0',
#     '20230812']
#
# Processing 178 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Iwona Fluda',
#     'With 7 people in that group now. I just try to understand the rules.',
#     'Unknown',
#     ' 0',
#     '20231110']
#
# Processing 179 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   '\u202a+381\xa062\xa08102423\u202c',
#     '\u200e\u202a+381\xa062\xa08102423\u202c left\n\u200e',
#     'Unknown',
#     ' 0',
#     '20230812']
#
# Processing 180 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231110']
#
# Processing 181 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20230812']
#
# Processing 182 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'No worries. Always Happy to clarify the rules that we all agreed upon 🙂🙏 '
#     '\u200e<This message was edited>\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20231110']
#
# Processing 183 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20230812']
#
# Processing 184 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eYou deleted this message.', 'Unknown', ' 0', '20231110']
#
# Processing 185 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eYou deleted this message.', 'Unknown', ' 0', '20230812']
#
# Processing 186 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Iwona Fluda',
#     'Cool - there are still just 7 people in this guilt, hope there is a new '
#     'one coming in.',
#     'Unknown',
#     ' 0',
#     '20231110']
#
# Processing 187 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'It is a recurring pattern I observe that whenever a person is attempting '
#     'to profit from information arbitrage, he/she will exhibit very cagey '
#     'behavioral patterns. \n'
#     '\n'
#     'This is especially true in the entire import and export business. \n'
#     '\n'
#     'I believe if we brought about 100% transparency in this vertical, we will '
#     'greatly disrupt the space. Based on what I have heard so far via the '
#     'extended network, depending on where we attempt to bring this disruption '
#     'to (especially in areas where cartels are in control), some of us might '
#     'even encounter assassination attempts. Sounds exciting... 🤔\n'
#     '\u200e',
#     'Unknown',
#     ' 0',
#     '20230812']
#
# Processing 188 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231110']
#
# Processing 189 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20230812']
#
# Processing 190 of 513:
# 'Contributed Human Effort; 9'
# ['Contributed Human Effort', ' 9']
# 2
# [   'Gary Teh',
#     'That is true. @557391090002 was recently invited out because when we did '
#     'an audit amongst ourselves he had no active scope \n'
#     '\n'
#     'Happy to introduce 1 more guild member who can commit time on a weekly '
#     'basis in there.  \n'
#     '\n'
#     'I know @972543523823 would be the 8th person but @31641075825 basically '
#     'interfaces all the communications for her and she rarely goes into group '
#     'chats\n'
#     '\n'
#     'I am aware Emelin is trying to onboard a new designer she can work '
#     'directly with. Not sure if that 8th should be used for him since feels '
#     'like Emelin will be interfacing with the new designer if he wants to '
#     'join \n'
#     '\n'
#     'But otherwise from what I am aware of so far we need these two additional '
#     'roles\n'
#     '\n'
#     '_Role 1_\n'
#     'a outreach marketing specialist who will take an active role to commit '
#     'time on a weekly basis to pitch our cacao nibs to retailers\n'
#     '\n'
#     '_role 2_\n'
#     'Marketing outreach specialist who can reach out to influencers to share '
#     'our stuff to their followers \u200e<This message was edited>',
#     'Contributed Human Effort',
#     ' 9',
#     '20231110']
#
# Processing 191 of 513:
# 'Contributed Human Effort; 0'
# ['Contributed Human Effort', ' 0']
# 2
# [   'Gary Teh',
#     '\u200eYou deleted this message.',
#     'Contributed Human Effort',
#     ' 0',
#     '20230812']
#
# Processing 192 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'Happy for anyone who would like to exercise *autonomy* by defining a '
#     'active role for himself/herself to take on within the scope of Agroverse '
#     'to join the guild to help advance the  project 🙂🙏\n'
#     '\n'
#     '*Autonomy* is one of our core values\n'
#     '\n'
#     '_PS: Also please don’t self define a role of being a manager to oversee '
#     'other members._\n'
#     '\n'
#     '_The guild size is small enough that members should be able to self '
#     'manage and self execute once given the instructions manual on how to '
#     'operate some functions_ 🤣 \u200e<This message was edited>',
#     'Unknown',
#     ' 0',
#     '20231110']
#
# Processing 193 of 513:
# 'Contributed Human Effort; 348TDG'
# ['Contributed Human Effort', ' 348TDG']
# 2
# [   'Gary Teh',
#     'I believe once our DAO gains the ability to certify a foreign supplier '
#     'under the FSVP program, we will be able to simply pay a visit to a '
#     'selected manufacturing facility in Colombia, give it our blessing, add it '
#     'to our Agroverse network and then start importing supplies from it. \n'
#     '\n'
#     'but first, we need to be able to shortlist ones that are qualified for '
#     "exports by the Colombian government before we engage one of our DAO's "
#     'FSVP qualified individual to undertake the inspection.\n'
#     '\n'
#     'I believe if we go the extend of notarizing all our FSVP inspections on '
#     'the blockchain we can start establishing a open database of foreign '
#     'suppliers than any enterprising retailer based in the USA can readily '
#     'choose from to co-manufacture their products with. \n'
#     '\n'
#     'And the primary difference between this database of suppliers versus the '
#     'other existing ones out there is that they are all USFDA FSVP validated, '
#     'streamlined and import ready. This also means that small scale retailers '
#     "don't need to go through all the bullshit that we navigated these past "
#     'six months before they can start bringing their produce into USA.\n'
#     '\u200e',
#     'Contributed Human Effort',
#     ' 348TDG',
#     '20230812']
#
# Processing 194 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231110']
#
# Processing 195 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20230812']
#
# Processing 196 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20231110']
#
# Processing 197 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted\n\u200e', 'Unknown', ' 0', '20230812']
#
# Processing 198 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231110']
#
# Processing 199 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200eYou deleted this message.\n\u200e',
#     'Unknown',
#     ' 0',
#     '20230813']
#
# Processing 200 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231110']
#
# Processing 201 of 513:
# 'Contributed Human Effort; 150 TDGs'
# ['Contributed Human Effort', ' 150 TDGs']
# 2
# [   'Gary Teh',
#     'Finished our 1.5 hours meeting between myself, @5511982667030 and '
#     '@16468233438 where we discussed about next steps on legal, logistics and '
#     'go to market via burning man',
#     'Contributed Human Effort',
#     ' 150 TDGs',
#     '20230813']
#
# Processing 202 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200eYou deleted this message.\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231110']
#
# Processing 203 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231110']
#
# Processing 204 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     'If we don’t see him here by the end of next week, then you know he got '
#     'lost in the boonies somewhere',
#     'Unknown',
#     ' 0',
#     '20231110']
#
# Processing 205 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Anupa/diya',
#     'Thats great! Yep. No pressure! 🤣\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231110']
#
# Processing 206 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eimage omitted', 'Unknown', ' 0', '20231110']
#
# Processing 207 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# ['Gary Teh', '\u200eYou deleted this message.', 'Unknown', ' 0', '20231110']
#
# Processing 208 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200eYou deleted this message.\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231110']
#
# Processing 209 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200e<attached: -0000008-PHOTO-2023-11-10-22-21-24.jpg>\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231110']
#
# Processing 210 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200e<attached: -0000007-PHOTO-2023-11-10-22-21-24.jpg>',
#     'Unknown',
#     ' 0',
#     '20231110']
#
# Processing 211 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200eYou deleted this message.\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231111']
#
# Processing 212 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200e<attached: -0000005-PHOTO-2023-11-11-01-03-57.jpg>\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231111']
#
# Processing 213 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200e<attached: -0000004-PHOTO-2023-11-11-09-03-08.jpg>\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231111']
#
# Processing 214 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200e<attached: -0000003-PHOTO-2023-11-11-09-11-51.jpg>\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231111']
#
# Processing 215 of 513:
# 'Unknown; 0'
# ['Unknown', ' 0']
# 2
# [   'Gary Teh',
#     '\u200e<attached: -0000002-PHOTO-2023-11-11-09-11-51.jpg>\n\u200e',
#     'Unknown',
#     ' 0',
#     '20231111']

# %%
analysis_file.close()
